# %% [markdown]
# project for finding gdp values with respect their countries.

# %%
import numpy as np



countries=np.array(['Algeria','Angola','Argentina','Australia','Austria','Bahamas','Bangladesh','Belarus','Belgium','Bhutan','Brazil','Bulgaria','Cambodia','Cameroon','Chile','China','Colombia','Cyprus','Denmark','El Salvador','Estonia','Ethiopia','Fiji','Finland','France','Georgia','Ghana','Grenada','Guinea','Haiti','Honduras','Hungary','India','Indonesia','Ireland','Italy','Japan','Kenya', 'South Korea','Liberia','Malaysia','Mexico', 'Morocco','Nepal','New Zealand','Norway','Pakistan', 'Peru','Qatar','Russia','Singapore','South Africa','Spain','Sweden','Switzerland','Thailand', 'United Arab Emirates','United Kingdom','United States','Uruguay','Venezuela','Vietnam','Zimbabwe'])


gdp=np.array([2255.225482,629.9553062,11601.63022,25306.82494,27266.40335,19466.99052,588.3691778,2890.345675,24733.62696,1445.760002,4803.398244,2618.876037,590.4521124,665.7982328,7122.938458,2639.54156,3362.4656,15378.16704,30860.12808,2579.115607,6525.541272,229.6769525,2242.689259,27570.4852,23016.84778,1334.646773,402.6953275,6047.200797,394.1156638,385.5793827,1414.072488,5745.981529,837.7464011,1206.991065,27715.52837,18937.24998,39578.07441,478.2194906,16684.21278,279.2204061,5345.213415,6288.25324,1908.304416,274.8728621,14646.42094,40034.85063,672.1547506,3359.517402,36152.66676,3054.727742,33529.83052,3825.093781,15428.32098,33630.24604,39170.41371,2699.123242,21058.43643,28272.40661,37691.02733,9581.05659,5671.912202,757.4009286,347.7456605])
max_gdp=gdp.argmax()
max_cont=countries[max_gdp]
print("maximum gdp of the country is- ", max_cont)
min_gdp=gdp.argmin()
min_cont=countries[min_gdp]
print("minimum gdp of the country is-",min_cont)
for i in countries:
  print(i)
for i in range(len(countries)):
   print("country-",countries[i],"--","gdp-",gdp[i])

print("maximum gdp is--",gdp.max())
print("minimum gdp is--",gdp.min())
print("means of gdp is--",gdp.mean())
print("sum of all gdp is--",gdp.sum())
# Out:
# maximum gdp of the country is-  Norway
# minimum gdp of the country is- Ethiopia
# Algeria
# Angola
# Argentina
# Australia
# Austria
# Bahamas
# Bangladesh
# Belarus
# Belgium
# Bhutan
# Brazil
# Bulgaria
# Cambodia
# Cameroon
# Chile
# China
# Colombia
# Cyprus
# Denmark
# El Salvador
# Estonia
# Ethiopia
# Fiji
# Finland
# France
# Georgia
# Ghana
# Grenada
# Guinea
# Haiti
# Honduras
# Hungary
# India
# Indonesia
# Ireland
# Italy
# Japan
# Kenya
# South Korea
# Liberia
# Malaysia
# Mexico
# Morocco
# Nepal
# New Zealand
# Norway
# Pakistan
# Peru
# Qatar
# Russia
# Singapore
# South Africa
# Spain
# Sweden
# Switzerland
# Thailand
# United Arab Emirates
# United Kingdom
# United States
# Uruguay
# Venezuela
# Vietnam
# Zimbabwe
# country- Algeria -- gdp- 2255.225482
# country- Angola -- gdp- 629.9553062
# country- Argentina -- gdp- 11601.63022
# country- Australia -- gdp- 25306.82494
# country- Austria -- gdp- 27266.40335
# country- Bahamas -- gdp- 19466.99052
# ...

# %% [markdown]
# project on ollympic 2012

# %%
import numpy as np
country=np.array(['Great Britain','China','Russia','United States','Korea','Japan','Germany' ])
country_code=np.array(['GBR','CHN','RUS','US','KOR','JPN','GER'])
year=np.array([2012,2012,2012,2012,2012,2012,2012])
gold=np.array([29,38,24,46,13,7,11])
silver=np.array([17,28,25,28,8,14,11])
bronze=np.array([19,22,32,29,7,17,14])
max_gold=gold.argmax()
print(country[max_gold],"--",country_code[max_gold])
more20_gold=gold>20
print(country[more20_gold])
for i in range(len(gold)):
  print("gold",gold[i],"silver",silver[i],"bronze",bronze[i])
for i in range(len(country)):
  print('country',country[i],'--','gold medals are',gold[i])
twod_arr=np.array([gold,silver,bronze]).transpose()
for i in range(len(gold)):
  print('country',country[i],'--totalmedals--',sum(twod_arr[i]))
# Out:
# United States -- US
# ['Great Britain' 'China' 'Russia' 'United States']
# gold 29 silver 17 bronze 19
# gold 38 silver 28 bronze 22
# gold 24 silver 25 bronze 32
# gold 46 silver 28 bronze 29
# gold 13 silver 8 bronze 7
# gold 7 silver 14 bronze 17
# gold 11 silver 11 bronze 14
# country Great Britain -- gold medals are 29
# country China -- gold medals are 38
# country Russia -- gold medals are 24
# country United States -- gold medals are 46
# country Korea -- gold medals are 13
# country Japan -- gold medals are 7
# country Germany -- gold medals are 11
# country Great Britain --totalmedals-- 65
# country China --totalmedals-- 88
# country Russia --totalmedals-- 81
# country United States --totalmedals-- 103
# country Korea --totalmedals-- 28
# country Japan --totalmedals-- 38
# country Germany --totalmedals-- 36
